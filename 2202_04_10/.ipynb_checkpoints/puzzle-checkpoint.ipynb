# %% [markdown]
# # Time to play the puzzle

# %% [markdown]
# Think of a five-letter word with an L that is pronounced. Add a letter at the start to get a six-letter word in which the L is silent. Then add a new letter in the fifth position to get a seven-letter word in which the L is pronounced again. What words are these?

# %% [markdown]
# Initial rationale/plan:
# - Start with a set of words from an NLTK dataset.
# - Find all five letter words that contain an L.
# - Find all six letter words that contain an L.
# - Find all seven letter words that contain an L.
# - Loop through the six letter words to narrow down to ones that contain one of the five letter words.
# - Loop through the seven letter words to narrow down to ones that share the first four letters with one of the six letter words.

# %% [markdown]
# ## Start with a dataset

# %% [markdown]
# We'll start by [downloading a corpus from NLTK](https://www.nltk.org/data.html) to use as our initial dataset. We're using the "words" corpus.

# %%
# NLTK dictionary

import nltk
from nltk.corpus import words

# %% [markdown]
# Next, we'll convert the corpus into a set.

# %%
# Convert words from corpus to a set to make it more efficient
wordset = set(words.words())

# %% [markdown]
# ## Find words of specific lengths containing the letter "L"

# %% [markdown]
# Next, we'll create sets of five, six, and seven letter words that contain the letter L.

# %% [markdown]
# Let's start with our set of five letter words:

# %%
# Create an empty set

fivers = set()

# Add five letter words containing "L" to the set

for word in wordset:
    if len(word) == 5 and "l" in word:
        fivers.add(word)

# %%
# Print fivers to spot check

print(fivers)
# Out:
# {'ileon', 'Galli', 'blame', 'swelt', 'bulse', 'Willy', 'tould', 'sloan', 'decal', 'flary', 'Duala', 'stalk', 'creel', 'gluer', 'dolor', 'salpa', 'tutly', 'laser', 'domal', 'bilio', 'bulla', 'nowel', 'monel', 'shaly', 'luxus', 'latus', 'telyn', 'lohan', 'ileum', 'slept', 'parol', 'linge', 'clary', 'loric', 'molal', 'alate', 'maral', 'poult', 'slish', 'limpy', 'Xylia', 'jural', 'loppy', 'delve', 'Olchi', 'rifle', 'pleat', 'venal', 'goloe', 'gluma', 'pylar', 'arsle', 'clout', 'bally', 'girly', 'Tecla', 'helio', 'sloop', 'welsh', 'billy', 'uloid', 'choli', 'palar', 'salve', 'palus', 'Jules', 'ruler', 'glaik', 'licit', 'lapse', 'bloat', 'sisal', 'plump', 'trull', 'lekha', 'livid', 'alkyl', 'anvil', 'haler', 'clite', 'legoa', 'Nilot', 'aloud', 'fecal', 'ogler', 'maleo', 'tiler', 'livor', 'cycle', 'longe', 'sally', 'bolis', 'lousy', 'lupis', 'sylva', 'redly', 'cooly', 'title', 'blick', 'Tilda', 'balei', 'louey', 'chill', 'malar', 'lingo', 'Kamel', 'glans', 'ratel', 'nodal', 'salle', 'aland', 'lindo', 'laney', 'kelty', 'dilly', 'blash', 'typal', 'Malay', 'boldo', 'blate', 'jolty', 'algae', 'excel', 'pilar', 'naval', 'laced', 'limma', 'larry', 'soler', 'aliso', 'guild', 'booly', 'sella', 'Atlas', 'garle', 'flane', 'float', 'hotly', 'salon', 'gemul', 'asale', 'culmy', 'floey', 'jelly', 'blout', 'Golgi', 'alien', 'glean', 'hulky', 'Oliva', 'Salol', 'steel', 'clava', 'manly', 'Melas', 'amula', 'flash', 'Salar', 'Della', 'brill', 'slash', 'dowel', 'glebe', 'alpha', 'lysin', 'tudel', 'folio', 'latro', 'lepra', 'ulnar', 'scler', 'velar', 'blibe', 'table', 'Aptal', 'nolle', 'selva', 'enrol', 'blown', 'bulge', 'Mabel', 'somal', 'didle', 'halse', 'dupla', 'gledy', 'scawl', 'cavil', 'Falco', 'luter', 'blase', 'Aluco', 'scale', 'apple', 'cline', 'genal', 'aluta', 'slane', 'fluey', 'dhyal', 'blank', 'trawl', 'holer', 'stole', 'gools', 'revel', 'sweal', 'Glenn', 'slave', 'Felup', 'helly', 'halma', 'cloop', 'nobly', 'pilot', 'algum', 'clift', 'poley', 'scall', 'xylyl', 'loser', 'Shluh', 'field', 'clark', 'slaky', 'calix', 'chalk', 'pelon', 'alack', 'clung', 'melam', 'snowl', 'pygal', 'gault', 'Salix', 'liber', 'milha', 'shilf', 'bluer', 'wield', 'snirl', 'cliff', 'pupil', 'ravel', 'loave', 'glaky', 'wryly', 'Eliza', 'aumil', 'dogly', 'plush', 'veldt', 'seral', 'khula', 'tally', 'moler', 'loamy', 'galea', 'algin', 'Wolof', 'elude', 'Tuzla', 'alloy', 'phyla', 'Algic', 'eusol', 'marly', 'plumy', 'aizle', 'holia', 'kerel', 'scaly', 'lucre', 'dally', 'Mosul', 'sadly', 'haole', 'thole', 'slete', 'Fultz', 'clang', 'paler', 'Vouli', 'tylus', 'slare', 'plash', 'clock', 'julep', 'gilse', 'Niels', 'tolan', 'choel', 'lemur', 'alway', 'sculp', 'lazar', 'weald', 'alist', 'artel', 'angle', 'jodel', 'elver', 'Klaus', 'plant', 'salad', 'relet', 'login', 'Somal', 'anoil', 'akule', 'anole', 'gules', 'lover', 'agley', 'filth', 'spile', 'spelk', 'allay', 'mohel', 'Belis', 'Eloah', 'blunt', 'Blair', 'yield', 'clame', 'ligne', 'Paola', 'bogle', 'Kolis', 'sowle', 'leath', 'scalp', 'Alida', 'folia', 'Lelia', 'elbow', 'olein', 'blanc', 'afoul', 'hazel', 'amply', 'liwan', 'islet', 'slime', 'slath', 'sowel', 'oxfly', 'golpe', 'uhllo', 'Natal', 'stola', 'yodel', 'plang', 'Babel', 'spell', 'Hamal', 'cilia', 'luteo', 'Celia', 'mools', 'whilk', 'flued', 'julio', 'clunk', 'letup', 'Melia', 'jewel', 'dayal', 'spole', 'poilu', 'ohelo', 'caryl', 'bilch', 'lisle', 'tulsi', 'owlet', 'looby', 'gavel', 'iliac', 'lulab', 'bluff', 'rigol', 'Sybil', 'alima', 'Colan', 'holla', 'Nicol', 'later', 'alody', 'lithe', 'parel', 'flung', 'Elric', 'Nigel', 'rowel', 'canel', 'picul', 'Dolph', 'below', 'alary', 'glime', 'Uriel', 'hemal', 'sinal', 'Fleta', 'alure', 'Elvis', 'Kelly', 'uhlan', 'clear', 'blind', 'lordy', 'algal', 'jokul', 'solon', 'jabul', 'sibyl', 'angel', 'anile', 'laver', 'uveal', 'cylix', 'Mugil', 'fluky', 'nucal', 'alamo', 'Waler', 'flick', 'vasal', 'llano', 'boyla', 'lysis', 'Dalea', 'Milla', 'loral', 'laura', 'blype', 'xylol', 'bowly', 'black', 'selly', 'Malva', 'belee', 'along', 'sh ...

# %% [markdown]
# Okay, looks like that kinda worked! Let's do the same for six and seven letter words containing "L"

# %%
# Create an empty set

sixers = set()

# Add six letter words containing "L" to the set

for word in wordset:
    if len(word) == 6 and "l" in word:
        sixers.add(word)

# %%
# Print sixers to spot check

print(sixers)
# Out:
# {'lucent', 'milium', 'dalton', 'alcine', 'Tanala', 'Kolush', 'eerily', 'agonal', 'levers', 'lyceal', 'burbly', 'nitryl', 'Angles', 'uncolt', 'Gifola', 'lapful', 'planky', 'cleach', 'vennel', 'colpeo', 'Alytes', 'pryler', 'Yildun', 'lessen', 'ceiler', 'infilm', 'angild', 'Lemuel', 'pommel', 'living', 'algate', 'measle', 'highly', 'sailor', 'hirple', 'rissle', 'oflete', 'phytyl', 'perlid', 'tablet', 'scaldy', 'idlish', 'damsel', 'inroll', 'howler', 'heloma', 'tumble', 'lambly', 'trabal', 'Pilpay', 'Belial', 'Tagula', 'column', 'iolite', 'gluish', 'hurler', 'dewily', 'russel', 'zingel', 'moiler', 'spleen', 'Gallus', 'Polian', 'sleyer', 'licorn', 'fennel', 'epical', 'taille', 'letten', 'discal', 'violer', 'auntly', 'probal', 'doiled', 'beheld', 'lummox', 'lumper', 'relime', 'candle', 'topply', 'talkie', 'galosh', 'bushel', 'calpac', 'loudly', 'gargle', 'bienly', 'trinol', 'plasma', 'oildom', 'venula', 'blotty', 'nimbly', 'dolent', 'relish', 'Cleome', 'clithe', 'joylet', 'bilbie', 'unslip', 'ultimo', 'peller', 'bridal', 'podial', 'korrel', 'sclate', 'pellar', 'flitch', 'polony', 'sculpt', 'lapser', 'psiloi', 'Beltir', 'filled', 'begall', 'aliped', 'unweel', 'reflux', 'lignum', 'sleeve', 'kahili', 'elbowy', 'nattle', 'lasher', 'leaven', 'flunky', 'wergil', 'alsoon', 'almond', 'murkly', 'allene', 'Altica', 'castle', 'fellow', 'jungly', 'paular', 'gleyde', 'amylic', 'lockup', 'Rotala', 'felony', 'barwal', 'coaler', 'basale', 'guglio', 'icicle', 'medial', 'swaler', 'rootle', 'unlade', 'tiffle', 'narial', 'boglet', 'cresyl', 'haloid', 'gleety', 'unroll', 'swirly', 'mickle', 'dulcet', 'taluto', 'jarful', 'penial', 'penult', 'entail', 'bleery', 'blooey', 'plumet', 'lauryl', 'goolah', 'matral', 'lector', 'Wilson', 'festal', 'Baltis', 'withal', 'kegler', 'furdel', 'Althea', 'lithic', 'dawdle', 'culbut', 'hassle', 'fylfot', 'apical', 'espial', 'bacule', 'lowder', 'babbly', 'Betula', 'globin', 'hummel', 'kelper', 'rebolt', 'Balolo', 'saltus', 'Ateles', 'cantle', 'frivol', 'cultus', 'laggar', 'pelvic', 'lustra', 'unhold', 'limbus', 'waxily', 'plodge', 'isohel', 'molest', 'alumna', 'replan', 'helper', 'molave', 'gelose', 'tancel', 'scolia', 'posole', 'reheal', 'kandol', 'kalema', 'rimula', 'Vulcan', 'kalpis', 'upline', 'blowze', 'rumbly', 'ecbole', 'aswirl', 'Alaric', 'amelus', 'ablush', 'unplat', 'muchly', 'ullage', 'solely', 'joggly', 'unlash', 'tandle', 'volata', 'bioral', 'stalko', 'aedile', 'befool', 'sporal', 'unpeel', 'wordle', 'relock', 'loving', 'tallis', 'avital', 'ruller', 'suddle', 'byplay', 'kimnel', 'gargol', 'acidyl', 'nextly', 'Tilsit', 'Fulgur', 'sunlet', 'unsoil', 'Taylor', 'Elanus', 'linker', 'Hillel', 'unlove', 'walker', 'saloop', 'waylay', 'milker', 'wingle', 'guttle', 'volupt', 'bauble', 'slinky', 'doudle', 'lysine', 'linked', 'ellops', 'dudler', 'beadle', 'featly', 'bacula', 'putlog', 'bharal', 'dimply', 'lather', 'Somali', 'relief', 'Sollya', 'apulse', 'aslant', 'filial', 'illess', 'Lolium', 'gallah', 'Galium', 'Rachel', 'claggy', 'slippy', 'blocky', 'police', 'Cullen', 'launce', 'bindle', 'sawfly', 'albata', 'toggle', 'cystal', 'couril', 'Moloch', 'gilguy', 'linear', 'ascula', 'witlet', 'cyclas', 'unheal', 'nasial', 'schola', 'unlimp', 'potful', 'alacha', 'Daedal', 'bumble', 'podley', 'rumply', 'meddle', 'rehaul', 'cabled', 'archly', 'killas', 'incult', 'Sialis', 'reflow', 'baldly', 'ooidal', 'svelte', 'cilice', 'boiled', 'galany', 'belted', 'slight', 'piddle', 'pilous', 'becall', 'cuspal', 'marled', 'cattle', 'regnal', 'lactim', 'vocule', 'gilder', 'langca', 'alnage', 'Hilary', 'boggle', 'podzol', 'deluge', 'splint', 'gilden', 'sluggy', 'sortal', 'hallan', 'thecal', 'snodly', 'belite', 'talcer', 'neatly', 'rebawl', 'ulluco', 'winkel', 'elutor', 'forlet', 'ligate', 'replod', 'bottle', 'hubble', 'spogel', 'joggle', 'uppull', 'lachsa', 'agleaf', 'Almida', 'koulan', 'lyxose', 'retill', 'Sylvan', 'ulcery', 'curple', 'poorly', 'slider', 'phlegm', 'luteal', 'bedolt', 'pokily', 'leachy', 'reckla', 'blobby', 'cledge', 'bleach', ...

# %%
# Create an empty set

sevens = set()

# Add seven letter words containing "L" to the set

for word in wordset:
    if len(word) == 7 and "l" in word:
        sevens.add(word)

# %%
# Print sevens to spot check

print(sevens)
# Out:
# {'besaiel', 'felling', 'lanated', 'flutina', 'toluido', 'helotry', 'scapula', 'ramular', 'volency', 'lordkin', 'foelike', 'fleetly', 'sterlet', 'jailage', 'victual', 'globule', 'scalena', 'bulkily', 'Chumulu', 'seedlet', 'belonid', 'weevily', 'elderly', 'horsily', 'clodlet', 'crisply', 'tenably', 'gemlike', 'caroler', 'balance', 'lounder', 'Fellani', 'holdout', 'Akhlame', 'triflet', 'ambital', 'truffle', 'noology', 'beerily', 'toughly', 'felucca', 'Onoclea', 'ductule', 'Tillaea', 'isocola', 'sondeli', 'Camelus', 'trailer', 'gazelle', 'outflux', 'Mechael', 'kindler', 'xylinid', 'blesbok', 'outtalk', 'thronal', 'nailery', 'Soxhlet', 'sleever', 'retinal', 'morular', 'skelpin', 'xanthyl', 'unworld', 'swaddle', 'mislear', 'outlimn', 'doodler', 'huvelyk', 'roundel', 'cutling', 'ailsyte', 'sewless', 'calipee', 'aralkyl', 'florula', 'stopple', 'deviler', 'waybill', 'Hylidae', 'ethynyl', 'hoverly', 'halling', 'limbous', 'clochan', 'skatole', 'Carolan', 'salviol', 'panicle', 'tralira', 'kanchil', 'exuvial', 'flether', 'doweral', 'fumaryl', 'lighter', 'humanly', 'rolling', 'Ampelis', 'inaptly', 'spikily', 'kidling', 'tumbled', 'limpkin', 'tylotic', 'voglite', 'plutean', 'epicele', 'pimlico', 'relight', 'chloryl', 'cullion', 'spondyl', 'oolemma', 'scolion', 'collins', 'kulaite', 'dislimn', 'delimit', 'plosion', 'cooling', 'Celtdom', 'podalic', 'glaceed', 'ephoral', 'basilar', 'hornful', 'nervily', 'beshell', 'bolster', 'clotter', 'cholate', 'subplot', 'volutin', 'butanal', 'beguile', 'codling', 'pikelet', 'unguled', 'Shelyak', 'Cyclops', 'imposal', 'sheenly', 'preboil', 'lutrine', 'knublet', 'gladify', 'pieless', 'trysail', 'trotlet', 'playbox', 'allgood', 'zeolite', 'rigidly', 'clerisy', 'pyloric', 'repolon', 'pyruvil', 'labiate', 'ratable', 'bowling', 'Alcoran', 'relaxed', 'simling', 'Elkanah', 'raggily', 'Estella', 'cadlock', 'fluting', 'lyncher', 'acridyl', 'Balunda', 'facular', 'chalaco', 'bairnly', 'lotrite', 'cannily', 'bitable', 'milreis', 'Lappula', 'rostral', 'Encelia', 'patball', 'bristly', 'travail', 'jellily', 'uphelya', 'calinut', 'fluking', 'mesilla', 'lovable', 'casalty', 'funicle', 'psalmic', 'unducal', 'blowzed', 'rowdily', 'factful', 'shelder', 'reptile', 'therial', 'Multani', 'solicit', 'murkily', 'flyless', 'fulling', 'Clarist', 'Calappa', 'torulin', 'haploma', 'fishlet', 'bitless', 'bemoult', 'crawful', 'retinol', 'ileitis', 'pallium', 'flattop', 'stickly', 'handsel', 'oltunna', 'claviol', 'peltate', 'mealies', 'ballade', 'sublime', 'ovalize', 'Khlysti', 'ridable', 'beveler', 'pretzel', 'Bumelia', 'wolfdom', 'pinlock', 'brinjal', 'dolcian', 'clacker', 'buckler', 'viruela', 'floorer', 'talkful', 'camphol', 'durable', 'bookful', 'realter', 'Pulayan', 'masculy', 'mislive', 'upfloat', 'reclaim', 'imperil', 'kinless', 'salacot', 'mildish', 'Templar', 'annulet', 'Ilokano', 'elusory', 'bollock', 'tipsily', 'Cellite', 'annulus', 'Biblist', 'reavail', 'scarily', 'englobe', 'wildish', 'studdle', 'alumium', 'fusilly', 'soberly', 'boodler', 'algesia', 'blaubok', 'optimal', 'jollily', 'gemless', 'plastin', 'myalism', 'bullety', 'astylar', 'illuder', 'estadal', 'nullify', 'guttule', 'flinger', 'Bengali', 'swayful', 'fadable', 'lehrman', 'polecat', 'alkoxyl', 'cowbell', 'slender', 'bizonal', 'ungloss', 'lambkin', 'blissom', 'Gadslid', 'clayish', 'cabling', 'pentail', 'thimble', 'pleonic', 'dewlike', 'dullish', 'outcull', 'cutlips', 'bloated', 'Cecilia', 'locoism', 'bipedal', 'plumage', 'Chilion', 'alamoth', 'orbless', 'slapper', 'warlock', 'audible', 'gutling', 'Caulite', 'sponsal', 'oarhole', 'Kartvel', 'Musales', 'enlarge', 'unheler', 'kiliare', 'Mitella', 'Taluche', 'mottled', 'panoply', 'gallows', 'replace', 'Orlando', 'cardial', 'basilic', 'validly', 'reimply', 'jurally', 'unslate', 'isolate', 'scaldic', 'cyclane', 'lentous', 'boulder', 'impling', 'hatless', 'Zincalo', 'tsatlee', 'melenic', 'visible', 'pyvuril', 'capreol', 'tastily', 'uncling', 'bluetop', 'scatula', 'rummily', 'ologist', 'Rellyan', 'figlike', 'inuloid', 'Icela ...

# %% [markdown]
# ## Compare sets of words

# %% [markdown]
# Now that we have our sets of five, six, and seven letter words containing the letter "L," let's check to see which of our six letter words contain our five letter words.
#
# Since the puzzle mentions adding a letter to the beginning of the five letter word to get the six letter word, we want to check to see if the five letter word appears in index 1-5 of the six letter word.

# %%
# Create an empty set then loop through words

matches = set()

for word in sixers:
    for wordle in fivers:
        if wordle == word[1:]:
            matches.add(word)

# %%
# Print new matches set to spot check

print(matches)

# Print length of each set to check logic

print(len(matches))
print(len(fivers))
print(len(sixers))
# Out:
# {'unable', 'nettle', 'belite', 'milium', 'atonal', 'pleach', 'aboral', 'methyl', 'stelar', 'gelder', 'sample', 'whilly', 'agonal', 'nunlet', 'acetyl', 'forlet', 'valley', 'Galibi', 'halite', 'boiler', 'aloose', 'travel', 'planky', 'cleach', 'warsle', 'golden', 'solder', 'slushy', 'Italon', 'frilly', 'dangle', 'enodal', 'strial', 'toiled', 'sloppy', 'afloat', 'galban', 'tallow', 'mumble', 'belute', 'amulla', 'glycid', 'Blayne', 'blaver', 'claver', 'fledge', 'alexia', 'blobby', 'flated', 'smiler', 'cledge', 'afetal', 'fettle', 'bleach', 'stilly', 'cingle', 'palter', 'glunch', 'pratal', 'mistle', 'damsel', 'oblate', 'aswell', 'elance', 'blunge', 'keeler', 'uplaid', 'blight', 'caddle', 'bolden', 'platen', 'flinty', 'howler', 'yolden', 'Lilium', 'wholly', 'shield', 'elaine', 'weasel', 'tumble', 'cledgy', 'slinge', 'alogia', 'glairy', 'skelly', 'burled', 'ablate', 'squalm', 'spilus', 'bursal', 'relate', 'luller', 'cartel', 'raptly', 'uplane', 'jumble', 'placet', 'hallow', 'sutile', 'fumble', 'culler', 'blower', 'golder', 'stable', 'moiler', 'stylus', 'ablest', 'torsel', 'glower', 'elench', 'stilty', 'slaker', 'slouch', 'Slavic', 'jangle', 'alevin', 'epical', 'apolar', 'aflame', 'finial', 'slimer', 'coiled', 'flinch', 'galgal', 'salamo', 'snavel', 'doiled', 'balter', 'agleam', 'tectal', 'delver', 'upheal', 'malign', 'nargil', 'sloper', 'clover', 'rumble', 'plover', 'stalky', 'delude', 'clysis', 'chield', 'anodal', 'coolly', 'clever', 'buller', 'slodge', 'afield', 'nearly', 'norsel', 'settle', 'bingle', 'flaser', 'azonal', 'gomlah', 'slowly', 'galley', 'salary', 'cangle', 'atrial', 'aglare', 'glaver', 'eloper', 'dolent', 'blurry', 'pontal', 'wumble', 'yallow', 'talose', 'bowler', 'blouse', 'clithe', 'cholla', 'churly', 'winkle', 'plunge', 'toiler', 'molder', 'Itylus', 'cample', 'drumly', 'soiled', 'Blaine', 'tramal', 'glacis', 'simply', 'Oliver', 'ballan', 'clough', 'screel', 'dental', 'shelly', 'slurry', 'flitch', 'valuta', 'slummy', 'plough', 'enable', 'gregal', 'plated', 'fuller', 'pearly', 'acarol', 'cletch', 'holden', 'velate', 'dossal', 'larval', 'palate', 'dismal', 'unoily', 'achill', 'kartel', 'wankle', 'astalk', 'welder', 'scavel', 'clinty', 'tingle', 'clammy', 'flodge', 'falter', 'fontal', 'shelve', 'mettle', 'primal', 'slater', 'flanky', 'flatus', 'hartal', 'sistle', 'foiler', 'plumpy', 'baylet', 'player', 'dapple', 'teasel', 'select', 'tinkle', 'plucky', 'aslope', 'kalong', 'atweel', 'aglint', 'helver', 'alight', 'capple', 'fangle', 'ballow', 'basale', 'flaker', 'blench', 'swaler', 'marvel', 'kamala', 'talite', 'Elaine', 'Salmon', 'snurly', 'teagle', 'baller', 'slatch', 'sclimb', 'elapse', 'floral', 'awhile', 'halter', 'gamble', 'hingle', 'awheel', 'oology', 'pistle', 'malter', 'bangle', 'fowler', 'glucid', 'belate', 'shamal', 'globed', 'haloid', 'thilly', 'limply', 'jingle', 'kettle', 'burial', 'chilly', 'carval', 'santal', 'tangle', 'squail', 'olease', 'duller', 'ramble', 'raylet', 'crotal', 'dorsel', 'plural', 'bleery', 'Walter', 'mangle', 'stroll', 'callow', 'slough', 'curled', 'batule', 'lauryl', 'atwirl', 'wamble', 'clinch', 'delate', 'uplook', 'blolly', 'mislay', 'damply', 'howlet', 'whelve', 'plater', 'holder', 'obolus', 'Calite', 'barvel', 'shewel', 'udaler', 'tripal', 'gravel', 'cental', 'reeler', 'Malloy', 'elicit', 'flower', 'scapel', 'ablare', 'slayer', 'hurled', 'choler', 'apical', 'osteal', 'clench', 'squeal', 'Aquila', 'walter', 'clarin', 'amoral', 'please', 'wangle', 'floppy', 'slaver', 'carvel', 'colder', 'tauryl', 'flurry', 'slithy', 'slitch', 'taglet', 'rangle', 'ballot', 'global', 'Illano', 'glance', 'thowel', 'dingle', 'elated', 'finlet', 'fluter', 'runlet', 'sblood', 'mental', 'plodge', 'glover', 'helide', 'plight', 'thoral', 'Salish', 'jowler', 'cleave', 'puller', 'beagle', 'cabler', 'maddle', 'hamble', 'jinkle', 'muller', 'paddle', 'peeler', 'slimsy', 'aflare', 'apodal', 'tergal', 'adital', 'flobby', 'phylic', 'blushy', 'chello', 'aswirl', 'ablush', 'Squill', 'blotto', 'glarry', 'blithe', 'waller', ...
# 615
# 2503
# 5554

# %% [markdown]
# Good! We've got 2503 five letter words containing the letter "L," 5554 six letter words containing the letter "L," and 615 matches, or words where the six letter word contains one of the five letter words.
#
# Do some of these words look made up? Yes. Would the last five letters of some of the six letter words appear to be made up words? Also yes. Before I get distracted and Google "knurly" and "twarly," let's see if we can narrow the field a bit more with our next check

# %%
# Okay, doing a little test to see if my logic makes sense

setone = {'valley', 'hiccup', 'relate'}
settwo = {'alley', 'elate', 'smell'}
overlap = set()

for word in setone:
    for wordle in settwo:
        if wordle == word[1:]:
            overlap.add(word)
            
print(overlap)
# Out:
# {'valley', 'relate'}

# %% [markdown]
# I think that worked?
#
# Now, we want to see if any of our seven letter words start with the same first four letters and end with the last two letters as one of our matched six letter words. I originally thought just checking the first four letters might be enough, but I'm starting to think that might not narrow it down enough! Just for fun, let's see how many seven letter words we have containing the letter "L".

# %%
print(len(sevens))
# Out:
# 8563

# %% [markdown]
# 8563! Yikes.
#
# Okay, well, let's see compare our matches to the seven letter words.

# %%
# Create an empty set for new matches and then compare sevens with matches

newset = set()

for seven in sevens:
    for match in matches:
        if seven[:4] == match[:4] and seven[5:] == match[4:]:
            newset.add(seven)

# %%
# Print count of the new set and the set itself

print(len(newset))

print(newset)
# Out:
# 41
# {'platter', 'stabile', 'choller', 'choreal', 'flasher', 'chorial', 'placket', 'slimpsy', 'udaller', 'platten', 'strigal', 'floreal', 'chordal', 'tallier', 'bladder', 'slather', 'waltzer', 'spiller', 'clavier', 'flasker', 'slatter', 'peartly', 'pistole', 'saltier', 'clarain', 'closter', 'stellar', 'palaite', 'filical', 'hallman', 'twinkly', 'childly', 'flutter', 'finical', 'soldier', 'platted', 'Olivier', 'pileous', 'grumbly', 'limpily', 'central'}

# %%
# Test case because I had the wrong thing above at first!

x = {'woolly', 'pelite', 'spiler'}
y = {'woolbly', 'pelbite', 'spilebr'}

test = set()

for i in y:
    for j in x:
        # print(j)
        # print(j[5:])
        if i[:4] == j[:4] and i[5:] == j[4:]:
            test.add(i)
            
print(test)
# Out:
# {'woolbly'}

# %% [markdown]
# Okay, now we're down to 41 words. This is looking pretty good! Let's see if we can get this into a view where we can see the three related words together so that we can determine which trio of words is the correct answer.

# %% [markdown]
# Let's loop through our 41 words and print out all three words in a row. We'll work backwards starting with the seven letter word, then removing the 5th letter to get our six letter word, and finally removing the first letter to get our five letter word. We probably could have been storing the word combinations as we went, but this should work too!

# %%
# Loop through the 41 words to see the word trios

for seven in newset:
    six = seven[:4] + seven[5:]
    five = six[1:]
    trio = [five, six, seven]
    print(trio)
# Out:
# ['later', 'plater', 'platter']
# ['table', 'stable', 'stabile']
# ['holer', 'choler', 'choller']
# ['horal', 'choral', 'choreal']
# ['laser', 'flaser', 'flasher']
# ['horal', 'choral', 'chorial']
# ['lacet', 'placet', 'placket']
# ['limsy', 'slimsy', 'slimpsy']
# ['daler', 'udaler', 'udaller']
# ['laten', 'platen', 'platten']
# ['trial', 'strial', 'strigal']
# ['loral', 'floral', 'floreal']
# ['horal', 'choral', 'chordal']
# ['aller', 'taller', 'tallier']
# ['lader', 'blader', 'bladder']
# ['later', 'slater', 'slather']
# ['alter', 'walter', 'waltzer']
# ['piler', 'spiler', 'spiller']
# ['laver', 'claver', 'clavier']
# ['laser', 'flaser', 'flasker']
# ['later', 'slater', 'slatter']
# ['early', 'pearly', 'peartly']
# ['istle', 'pistle', 'pistole']
# ['alter', 'salter', 'saltier']
# ['larin', 'clarin', 'clarain']
# ['loser', 'closer', 'closter']
# ['telar', 'stelar', 'stellar']
# ['alate', 'palate', 'palaite']
# ['ilial', 'filial', 'filical']
# ['allan', 'hallan', 'hallman']
# ['winly', 'twinly', 'twinkly']
# ['hilly', 'chilly', 'childly']
# ['luter', 'fluter', 'flutter']
# ['inial', 'finial', 'finical']
# ['older', 'solder', 'soldier']
# ['lated', 'plated', 'platted']
# ['liver', 'Oliver', 'Olivier']
# ['ileus', 'pileus', 'pileous']
# ['rumly', 'grumly', 'grumbly']
# ['imply', 'limply', 'limpily']
# ['ental', 'cental', 'central']

# %% [markdown]
# Okay! Now we need some human power to determine which set matches the puzzle: Think of a five-letter word with an L that is pronounced. Add a letter at the start to get a six-letter word in which the L is silent. Then add a new letter in the fifth position to get a seven-letter word in which the L is pronounced again. What words are these?

# %% [markdown]
# I had to Google it, but I'm going with 'older', 'solder', and 'soldier'! It seems that the "L" in 'solder' is typically not pronounced in American English, but it is in British English. I learned something new!
